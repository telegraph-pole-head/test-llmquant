# %%
from llama_cpp import Llama


llm = Llama(
    model_path="/data/llmQuantModels/gemma-2-2b-it-gguf/gemma-2-2b-it.q2_k.gguf",
    chat_format="gemma"
)
# Out:
# llama_model_loader: loaded meta data with 35 key-value pairs and 288 tensors from /data/llmQuantModels/gemma-2-2b-it-gguf/gemma-2-2b-it.q2_k.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = gemma2
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Gemma 2 2b It
# llama_model_loader: - kv   3:                            general.version str              = 2
# llama_model_loader: - kv   4:                       general.organization str              = Google
# llama_model_loader: - kv   5:                           general.finetune str              = it
# llama_model_loader: - kv   6:                           general.basename str              = gemma-2
# ...

# %%
llm.create_chat_completion(
    messages = [
        {"role": "system", "content": "You are a chat assistant"},
        {
            "role": "user",
            "content": "write me a joke"
        }
    ]
)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    3510.00 ms
# llama_print_timings:      sample time =       7.27 ms /    39 runs   (    0.19 ms per token,  5367.46 tokens per second)
# llama_print_timings: prompt eval time =    1621.40 ms /     6 tokens (  270.23 ms per token,     3.70 tokens per second)
# llama_print_timings:        eval time =    1305.13 ms /    38 runs   (   34.35 ms per token,    29.12 tokens per second)
# llama_print_timings:       total time =    2993.02 ms /    44 tokens
# {'id': 'chatcmpl-17ba9ca0-727e-46e8-acc8-d6d82c731d73',
#  'object': 'chat.completion',
#  'created': 1722519301,
#  'model': '/data/llmQuantModels/gemma-2-2b-it-gguf/gemma-2-2b-it.q2_k.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant',
#     'content': "Why did the scarecrow win an award?\n\nBecause he was outstanding in his field! 🎃 \n\nLet me know if you'd like to hear another one! 😄 \n"},
#    'logprobs': None,
# ...
